# %%
#import dependencies
import pandas as pd

# %%
#Load data
nyc_bike = "202001-citibike-tripdata.csv"

bike_load = pd.read_csv(nyc_bike)

# %%
#Calculate Age
bike_year = bike_load['birth year']

age_list = []

for y in bike_year:
    biker_age = 2020 - y
    age_list.append(biker_age)

# %%
bike_load['gender'].replace([0,1,2],['Unknown','Male','Female'],inplace=True)

bike_load['age'] = age_list

bike_load
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1                1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2                1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3                 592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4                 702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...               ...                       ...                       ...
# 1240591          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 1240592           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 1240593           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 1240594           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 1240595           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#          start station id               start station name  \
# ...

# %%
groupby_user = bike_load.groupby('usertype')

groupby_user['usertype'].count()
# Out:
# usertype
# Customer        94777
# Subscriber    1145819
# Name: usertype, dtype: int64

# %%
bike_load.max()
# Out:
# tripduration                                    1952746
# starttime                      2020-01-31 23:59:57.0360
# stoptime                       2020-02-04 08:42:03.2980
# start station id                                   3918
# start station name         Wythe Ave & Metropolitan Ave
# start station latitude                          40.8183
# start station longitude                        -73.8979
# end station id                                     3918
# end station name           Wythe Ave & Metropolitan Ave
# end station latitude                            40.8183
# end station longitude                          -73.8979
# bikeid                                            42091
# usertype                                     Subscriber
# birth year                                         2004
# gender                                          Unknown
# age                                                 135
# dtype: object

# %%
cleaned_data = bike_load
# cleaned_data.max()

# %%
cleaned_data.to_csv("cleaned_nyc_data.csv",index=False)
